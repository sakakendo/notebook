# %%
print("hello jupyter notebook")
# Out:
# hello jupyter notebook

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x=np.random.randint(0,100,10000)
plt.hist(x,bins=20)
plt.plot()
# Out:
# []

# %%
def fib():
    a,b=1,0
    for i in range(100):
        a,b=a+b,a
    print(a)
    
# %timeit fib()
# Out:
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# 573147844013817084101
# ...

# %%
# %load_ext Cython

# %%cython

def fib():
    a,b=1,0
    for i in range(100):
        a,b=a+b,a
    print(a)
    
# %timeit fib()
# Out:
#   File "<ipython-input-12-de2d504bee8d>", line 3
#     %%cython
#     ^
# SyntaxError: invalid syntax

# %%
# %load_ext Cython
# %%cython
for i in range(100):
    print(i)
# Out:
#   File "<ipython-input-13-7c623129f813>", line 2
#     %%cython
#     ^
# SyntaxError: invalid syntax

# %% [raw]
# \begin{align}

# %% [raw]
# \begin{align}

# %%
\end{align}
# Out:
#   File "<ipython-input-14-54e502454cf3>", line 1
#     \end{align}
#                ^
# SyntaxError: unexpected character after line continuation character

# %% [raw]
# \begin{align}
#
# \end{align}
