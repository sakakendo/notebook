# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sakakendo0321/notebook/blob/master/apm1_1.ipynb)

# %% [markdown]
# # 応用I(フーリエ) 課題1
#
#
# [演習1]
#
# $
# (1)T=\frac{1}{10}=0.1 \\
# (2)\omega=\frac{2}{T}=20\pi \\
# (3)f=\frac{1}{250\times10^-6}=4\cdot10^3[sec] \\
# (4)\omega=2\pi f=8\pi\cdot10^3[rad/s]$

# %%
#@title (5)
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(6,3))
x = np.arange(0, 1,0.01)
y = np.sin(2*3.14*x)
plt.xlabel("Time [s]", fontsize=20, fontname='serif')

plt.plot(x, y)

# %% [markdown]
# $(6)T=1[sec]\ \ \ \ \omega=2\pi[rad/s]$

# %%
#@title (7)
import matplotlib.pyplot as plt
import math
import numpy as np
plt.figure(figsize=(6,3))
x = np.arange(0, 1,0.001)
y = np.sin(2*math.pi*(x)+math.pi/4)
plt.xlabel("Time [s]", fontsize=20, fontname='serif')
plt.plot(x,y)

# %% [markdown]
# $\\ \\ \ \ \ \ \ \ f(t)=r\sin(2\pi t-\pi/4)=r\cdot cos(2\pi t+\pi/2)\\
# (8)\         f(t)=r\sin(2\pi t-\pi/2)=r\cdot cos(2\pi t)\\ \\ $

# %%
#@title [演習2] 
import matplotlib.pyplot as plt
import math
import numpy as np
plt.figure(figsize=(6,3))
x = np.arange(-0.02, 0.02,0.0001)
y = 10*np.cos(100*math.pi*x)
plt.xlabel("Time [s]", fontsize=20, fontname='serif')
plt.plot(x,y)
