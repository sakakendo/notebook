# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sakakendo0321/notebook/blob/master/apm1_10.ipynb)

# %% [markdown]
# # 応数 Ⅰ (フーリエ) 課題10
# ### フーリエ変換
# <div align='right'><u>H30年度</u></div>

# %% [markdown]
# [演習1]
# 1)
# $
# f(t)=x(t)2\cdot g(t)\\=2x(t)cos(\omega_0 t)\\
# F(\omega)=X(\omega+\omega_0)+X(\omega-\omega_0)
# $

# %%
#@title (2)
import math
import numpy as np
from matplotlib import pyplot
pyplot.figure(figsize=(10,1),dpi=100)
pyplot.plot([-1010,-1000,-990,990,1000,1010],[0,10,0,0,10,0]) #9Hz

pyplot.xticks([-1000,1000],[-1000,1000])

pyplot.xlabel('ω[rad/s]')
pyplot.ylabel('F(ω)')
pyplot.show()

# %% [markdown]
# 3)
#
# $y(t)=x(t)\cdot 2cos^2{\omega_0 t}=2\cdot \frac{1}{2} x(t)+\frac{1}{2} x(t)\cdot \cos{2\omega_0 t} \leftrightarrow Y(\omega)=X(\omega)+\frac{1}{2}\{ X(\omega-2\omega_0)+X(\omega+2\omega_0)\}$

# %%
#@title [演習2]
import math
import numpy as np
from matplotlib import pyplot

x = np.linspace(0, 1000, 100000)  #0から2πまでの範囲を100分割したnumpy配列
pyplot.figure(figsize=(16/2,9/2),dpi=100)
#pyplot.plot(x, np.sin(1/50*np.pi*x))   #10Hz
pyplot.plot(x, np.sin(18*np.pi*x/1000)) #9Hz
pyplot.plot(x, -np.sin(2*np.pi*x/1000)) #1Hz
pyplot.xticks(range(0,1001,100),range(0,10001,100))

pyplot.xlabel('t[ms]')
pyplot.ylabel('y(t)')
pyplot.show()
