# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sakakendo0321/notebook/blob/master/parse_featured_article.ipynb)

# %%
#!pip3 install wikipedia



import wikipedia
wikipedia.set_lang('en')

#print(wikipedia.summary('John_f._Kennedy'))
for title in wikipedia.random(pages=10):
  page=wikipedia.page(title)
  print(page.title,page.url,page.content)
  
  #print(wikipedia.summary(page),wikipedia.page(title).content)
  #print(page,wikipedia.page(page).categories)
# Out:
# Rarities, B-Sides and Other Stuff https://en.wikipedia.org/wiki/Rarities,_B-Sides_and_Other_Stuff Rarities, B-Sides & Other Stuff is a 1996 album by Sarah McLachlan.
# It is a compilation of tracks that McLachlan recorded for film soundtracks, remixes of McLachlan's songs, and material that she recorded in collaboration with other artists.
# Guest musicians appearing on the album include Deni Bonet, Jocelyne Lanois, Bill Dillon, Luke Doucet, Manufacture and Camille Henderson; remixers include Anthony Valcic, Gary Stokes and Rabbit in the Moon.
# The song "Full of Grace" later reappeared as the ninth track on McLachlan's next album, Surfacing. The extended remix of "Vox" first appeared on the 1989 release of her debut album, Touch.
#
#
# == Track listing ==
#
#
# == Charts ==
#
#
# == Certifications and sales ==
#
#
# == See also ==
# Rarities, B-Sides and Other Stuff Volume 2
#
#
# == References ==
# ...

# %%
#!pip3 install bs4 request
import bs4
from bs4 import BeautifulSoup
import requests

indexes=[]
articles={}

r=requests.get('https://en.wikipedia.org/wiki/Wikipedia:Featured_articles#Engineering_and_technology')
print(r.status_code)
if r.status_code != 200:
  print('request failed')
  exit()

soup=BeautifulSoup(r.text,'html.parser')
#print(soup.head,soup.body)
td=soup.body.find_all('td',class_='hlist')
#print(type(td),len(td))
#print(type(td[0]))
for child in td[1].children:
  #print(child)
  #print(child)
  if type(child) is bs4.element.NavigableString:
    #print("NavagableString",child.string)
    pass
  elif type(child) is bs4.element.Tag:
    #print('Tag',child.name,child.attrs,child.contents)
    if child.name == 'h2' and child.contents[0].name == 'span':
      index=child.contents[0].contents
      print('index',index)
      indexes.append(index)
      if len(index)==1 and index[0]=='History':print('found history index')
    else:
      index=''
    if child.name =='ul':
      #print('Unorederd list')
      for li in child.contents:
        #print('li',li)
        if type(li) is bs4.element.Tag :
          #print(li.contents[0])
          if li.contents[0].name == 'span':
            #print(li.contents[0].get('class'))
            if 'featured_article_metadata' in li.contents[0].get('class') and 'has_been_on_main_page' in li.contents[0].get('class'):
              #print('index is ',indexes[-1])
              if li.contents[0].contents[0].name=='a':
                print('article is {',li.contents[0].contents[0].get('href'),',',li.contents[0].contents[0].contents[0],'}')
                '''
                if indexes[-1] == []: key='Nocategory'
                else :key=indexes[-1]

                if articles.get(key) is None:  
                  articles[key]=[{li.contents[0].contents[0].get('href'),li.contents[0].contents[0].contents[0]}]
                else:
                  articles[key].append({li.contents[0].contents[0].get('href'),li.contents[0].contents[0].contents[0]})
                  '''
        #if li.contents[0].name =='span' and li.contents[0].get('class') == 'featured_article_metadata has_been_on_main_page':
        #  print('found featured_article_metadata has_been_on_main_page',li)

        
print(indexes)
for item in articles.items():
  print(item)
  
'''
articles={
  'index':[{'name':'url'},{'name':'url'}],
  '':[]
}

'''

'''
    for c in child.children:
      if type(c)  is bs4.element.NavigableString:# and c.string =='History'
        print("child's children",c.string)
        '''
# Out:
# 200
# index []
# article is { /wiki/7_World_Trade_Center , 7 World Trade Center }
# article is { /wiki/Acra_(fortress) , Acra (fortress) }
# article is { /wiki/Angkor_Wat , Angkor Wat }
# article is { /wiki/Anthony_Roll , Anthony Roll }
# article is { /wiki/Belton_House , Belton House }
# article is { /wiki/Blakeney_Chapel , Blakeney Chapel }
# article is { /wiki/Bodiam_Castle , Bodiam Castle }
# article is { /wiki/Book_of_Kells , Book of Kells }
# article is { /wiki/Borobudur , Borobudur }
# article is { /wiki/Boydell_Shakespeare_Gallery , Boydell Shakespeare Gallery }
# article is { /wiki/Bramall_Hall , Bramall Hall }
# article is { /wiki/Brougham_Castle , Brougham Castle }
# article is { /wiki/Bruce_Castle , Bruce Castle }
# article is { /wiki/Buckingham_Palace , Buckingham Palace }
# article is { /wiki/Buildings_and_architecture_of_Bristol , Buildings and architecture of Bristol }
# article is { /wiki/Buildings_of_Jesus_College,_Oxford , Buildings of Jesus College, Oxford }
# ...
